# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This is our evolution notebook and it will be so cool.

# %%
# !pip install krpc

# %%
import os

# List top-level folders in your Drive
print(os.listdir('/content/drive/MyDrive'))
# Out:
# ['Colab Notebooks', 'Financial', 'House', 'Kid Stuff', 'Misc', 'Legal', 'Notability', 'College Preparation', 'Education', 'Obsidian_Vault', 'Letter.gdoc', 'keplers_third_law.md.gdoc', 'Copy of Backrooms First Person Series Plot.gdoc']

# %%
import krpc
